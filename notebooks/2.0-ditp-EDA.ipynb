# %%
# Use if working in colab
from google.colab import drive
drive.mount('/content/drive')

# %%
# Use if working in colab
# set working directory to project directory
# %cd '/content/drive/My Drive/github/bicycles-seoul'

# %%
# Efficiently check for dtypes, non-null values, unique values, NaN values. Seen this done elsewhere as a function

# %%
# Extract day, month, year and clean time variables

# %%
# Divide the variables into numeric and categoric, and analyse accordingly

# %%
# REMEMBER: REMOVE NON-FUNCTIONING DAY VARIABLE AND NON-FUNCTIONING DAY CASES

# %%
# Save as csv in Drive
df.to_csv('data/interim/02-data-after-EDA.csv', index=False)
