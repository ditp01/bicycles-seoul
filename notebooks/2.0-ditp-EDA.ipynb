# %%
import pandas as pd
import plotly.express as px

# %%
# Use if working in colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Use if working in colab
# set working directory to project directory
# %cd '/content/drive/My Drive/github/bicycles-seoul'
# Out:
# /content/drive/My Drive/github/bicycles-seoul

# %%
df = pd.read_csv('data/interim/01-merged-data.csv')

# %%
df.head()
# Out:
#    Hour  Temperature(C)  Humidity(%)  Wind speed (m/s)  Visibility (10m)  \
# 0     0            -5.2           37               2.2              2000
# 1     1            -5.5           38               0.8              2000
# 2     2            -6.0           39               1.0              2000
# 3     3            -6.2           40               0.9              2000
# 4     4            -6.0           36               2.3              2000
#
#    Dew point temperature(C)  Solar Radiation (MJ/m2)  Rainfall(mm)  \
# 0                     -17.6                      0.0           0.0
# 1                     -17.6                      0.0           0.0
# 2                     -17.7                      0.0           0.0
# 3                     -17.6                      0.0           0.0
# 4                     -18.6                      0.0           0.0
#
#    Snowfall (cm) Seasons  ...  year week_day   timestamp             datetime  \
# ...

# %%
# Efficiently check for dtypes, non-null values, unique values, NaN values.

def summarize_df(df):
    summary = pd.DataFrame({
        'Data Type': df.dtypes,
        'Non-Null Count': df.notnull().sum(),
        'Unique Values': df.nunique(),
        'NaN Count': df.isnull().sum()
    })
    return summary


summary = summarize_df(df)
print(summary)
# Out:
#                          Data Type  Non-Null Count  Unique Values  NaN Count
# Hour                         int64            8760             24          0
# Temperature(C)             float64            8760            546          0
# Humidity(%)                  int64            8760             90          0
# Wind speed (m/s)           float64            8760             65          0
# Visibility (10m)             int64            8760           1789          0
# Dew point temperature(C)   float64            8760            556          0
# Solar Radiation (MJ/m2)    float64            8760            345          0
# Rainfall(mm)               float64            8760             61          0
# Snowfall (cm)              float64            8760             51          0
# Seasons                     object            8760              4          0
# Holiday                     object            8760              2          0
# ...

# %%
df.describe().T
# Out:
#                            count          mean           std           min  \
# Hour                      8760.0  1.150000e+01  6.922582e+00  0.000000e+00
# Temperature(C)            8760.0  1.288292e+01  1.194483e+01 -1.780000e+01
# Humidity(%)               8760.0  5.822626e+01  2.036241e+01  0.000000e+00
# Wind speed (m/s)          8760.0  1.724909e+00  1.036300e+00  0.000000e+00
# Visibility (10m)          8760.0  1.436826e+03  6.082987e+02  2.700000e+01
# Dew point temperature(C)  8760.0  4.073813e+00  1.306037e+01 -3.060000e+01
# Solar Radiation (MJ/m2)   8760.0  5.691107e-01  8.687462e-01  0.000000e+00
# Rainfall(mm)              8760.0  1.486872e-01  1.128193e+00  0.000000e+00
# Snowfall (cm)             8760.0  7.506849e-02  4.367462e-01  0.000000e+00
# rented_bike_count         8760.0  7.046021e+02  6.449975e+02  0.000000e+00
# day                       8760.0  1.572055e+01  8.796749e+00  1.000000e+00
# ...

# %%
# Day, month, year, hour, and weekday have already been extracted from timestamp/datetime, so drop timestamp/datetime.

df = df.drop(columns=['timestamp', 'datetime'])

# %%
# Divide the variables into numeric and categoric, and analyse accordingly

# %%
# What is functioning day, and what relationship does it bear to rented bike count?

fig = px.bar(
    df.groupby("Functioning Day")["rented_bike_count"].sum().reset_index(),
    x="Functioning Day",
    y="rented_bike_count",
    title="Total Rented Bike Count by Functioning Day",
    labels={"rented_bike_count": "Total Bike Count", "Functioning Day": "Functioning Day"}
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Functioning Day determines whether the bike service is running - so needs to be removed.
# Drop all cases where Functioning Day = No. Then delete Functioning Day variable.

print('shape before modification', df.shape)
df = df[df["Functioning Day"] != "No"]
df = df.drop(columns=["Functioning Day"])
print('shape after modification', df.shape)
# Out:
# shape before modification (8760, 23)
# shape after modification (8465, 22)

# %%
# Save as csv in Drive
df.to_csv('data/interim/02-data-after-EDA.csv', index=False)
